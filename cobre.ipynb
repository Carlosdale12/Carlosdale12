# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlosdale12/Carlosdale12/blob/main/cobre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar yfinance si no está instalado
# !pip install yfinance --quiet

# Importar librerías
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Descargar datos del tipo de cambio USD/CLP
moneda = 'CLP=X'
datos = yf.download(moneda, start='2020-01-01', end='2025-04-05')

# Verifica columnas disponibles
print("Columnas disponibles:", datos.columns)

# Usamos 'Close' en lugar de 'Adj Close'
datos['Rentabilidad'] = np.log(datos['Close'] / datos['Close'].shift(1))

# Calcular rentabilidad anualizada y volatilidad anualizada
rentabilidad_promedio = datos['Rentabilidad'].mean() * 252
volatilidad = datos['Rentabilidad'].std() * np.sqrt(252)

print(f"\nRentabilidad anual promedio: {rentabilidad_promedio:.4f}")
print(f"Volatilidad anual (riesgo): {volatilidad:.4f}")

# Graficar resultados
plt.figure(figsize=(14, 6))

plt.subplot(2, 1, 1)
plt.plot(datos['Close'], label='USD/CLP (Close)', color='blue')
plt.title('Tipo de Cambio USD/CLP')
plt.ylabel('CLP por USD')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(datos['Rentabilidad'], label='Rentabilidad diaria (log)', color='green')
plt.title('Rentabilidad Diaria USD/CLP')
plt.xlabel('Fecha')
plt.ylabel('Rentabilidad')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Columnas disponibles: MultiIndex([( 'Close', 'CLP=X'),
#             (  'High', 'CLP=X'),
#             (   'Low', 'CLP=X'),
#             (  'Open', 'CLP=X'),
#             ('Volume', 'CLP=X')],
#            names=['Price', 'Ticker'])
#
# Rentabilidad anual promedio: 0.0460
# Volatilidad anual (riesgo): 0.1732

# %%
# Descargar datos del cobre (HG=F)
cobre = 'HG=F'
datos = yf.download(cobre, start='2020-01-01', end='2025-04-05')

# Mostrar columnas disponibles
print("Columnas disponibles:", datos.columns)

# Calcular rentabilidad logarítmica
datos['Rentabilidad'] = np.log(datos['Close'] / datos['Close'].shift(1))

# Calcular estadísticas anuales
rentabilidad_promedio = datos['Rentabilidad'].mean() * 252
volatilidad = datos['Rentabilidad'].std() * np.sqrt(252)

print(f"\nRentabilidad anual promedio (Cobre): {rentabilidad_promedio:.4f}")
print(f"Volatilidad anual (riesgo): {volatilidad:.4f}")

# Graficar resultados
plt.figure(figsize=(14, 6))

plt.subplot(2, 1, 1)
plt.plot(datos['Close'], label='Precio del Cobre (USD/lb)', color='orange')
plt.title('Precio del Cobre - Contrato HG=F')
plt.ylabel('USD por libra')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(datos['Rentabilidad'], label='Rentabilidad diaria (log)', color='green')
plt.title('Rentabilidad Diaria del Cobre')
plt.xlabel('Fecha')
plt.ylabel('Rentabilidad')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Columnas disponibles: MultiIndex([( 'Close', 'HG=F'),
#             (  'High', 'HG=F'),
#             (   'Low', 'HG=F'),
#             (  'Open', 'HG=F'),
#             ('Volume', 'HG=F')],
#            names=['Price', 'Ticker'])
#
# Rentabilidad anual promedio (Cobre): 0.0832
# Volatilidad anual (riesgo): 0.2446

# %%
# Descargar datos del S&P 500
sp500 = '^GSPC'
datos = yf.download(sp500, start='2020-01-01', end='2025-04-05')

# Mostrar columnas disponibles
print("Columnas disponibles:", datos.columns)

# Calcular rentabilidad logarítmica diaria
datos['Rentabilidad'] = np.log(datos['Close'] / datos['Close'].shift(1))

# Calcular estadísticas anuales
rentabilidad_promedio = datos['Rentabilidad'].mean() * 252
volatilidad = datos['Rentabilidad'].std() * np.sqrt(252)

print(f"\nRentabilidad anual promedio (S&P 500): {rentabilidad_promedio:.4f}")
print(f"Volatilidad anual (riesgo): {volatilidad:.4f}")

# Graficar resultados
plt.figure(figsize=(14, 6))

plt.subplot(2, 1, 1)
plt.plot(datos['Close'], label='S&P 500 (Close)', color='navy')
plt.title('Índice S&P 500 - Bolsa de EE.UU.')
plt.ylabel('Puntos del índice')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(datos['Rentabilidad'], label='Rentabilidad diaria (log)', color='teal')
plt.title('Rentabilidad Diaria del S&P 500')
plt.xlabel('Fecha')
plt.ylabel('Rentabilidad')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Columnas disponibles: MultiIndex([( 'Close', '^GSPC'),
#             (  'High', '^GSPC'),
#             (   'Low', '^GSPC'),
#             (  'Open', '^GSPC'),
#             ('Volume', '^GSPC')],
#            names=['Price', 'Ticker'])
#
# Rentabilidad anual promedio (S&P 500): 0.0845
# Volatilidad anual (riesgo): 0.2148
